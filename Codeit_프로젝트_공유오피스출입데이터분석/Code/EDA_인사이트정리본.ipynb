# %% [markdown]
# # EDA 정리

# %% [markdown]
# ## 1. `last_site_id` 별 결제율

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | last\_site\_id | 미결제(0) | 결제(1) |
# | -------------- | ------ | ----- |
# | 1              | 403    | 261   |
# | 2              | 607    | 301   |
# | 3              | 669    | 421   |
# | 4              | 219    | 140   |
# | 5              | 292    | 239   |
# | 6              | 749    | 386   |
# | 17             | 254    | 132   |
# | 47             | 195    | 92    |
# | 49             | 76     | 46    |
#
# <br>
#
# 카이제곱 통계량: 32.43030668142754
# 자유도: 8
# p-value: 7.797807106316638e-05

# %% [markdown]
# - 지점별 결제율 분포
#   - 최고 : 5번 지점(45%)
#   - 최저 : 47번 지점(32.1%)
#   - 대체로 32 ~ 45% 사이 분포
#
# - 통계검정
#   - 카이제곱 사용
#   - p값으로 봤을 때 통계적으로 유의미한 결과이다.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 2. 총 체류시간(`stay_time_second_total`)과 결제여부(`is_payment`)와의 관계

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 참고용 : 각 유저의 평균 체류 시간(`avg_stay_time`) 과 결제여부(`is_payment`)와의 관계

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 총 체류시간(`stay_time_second_total`)
#   - 결제 그룹과 미결제 그룹의 분포가 크게 다르지 않음
#   - 다만 아주 긴 체류(극단값)까지 포함해도 결제 여부에 따라 뚜렷한 경향 차이는 확인하기 어려움
# - 평균 체류시간(`avg_stay_time`)
#   - 분포를 보면 오히려 결제 그룹이 짧은 시간대에 몰려있음
#   - 미 결제그룹은 체류시간이 더 김
#   - ★ **오래 머무른다고 반드시 결제론 이어지지 않는 것을 의미**

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. 연도별 결제율 파악

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 21년도 : 6월 부터 시작 & 급격한 상승 : 해당 시점 오픈 효과 or 당시 개업 이벤트? 가능성 존재
# - 22년도 : 전반적으로 비슷한 결제율을 보여줌
# - 23년도 : 연초 ~ 중순 까진 우상향인 그래프지만 5월 기점부터 연말까지 하락세를 보임
# - 24년도 : 데이터 극소수

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 4. 코로나 와 결제 여부와의 관계

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# - 아이러니하게도 강도가 높은 지점에 결제율이 가장 높게 나옴
# - 박스플롯 및 바 플롯으로 이뤄 봤을 땐 단계에 따라서 큰 차이는 없어보임

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 5. 체험 일수(trial_day)와 결제여부(is_payment)의 관계

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 카이제곱 결과
# χ² = 77.55
# p-value=0.0000

# %% [markdown]
# - **하루 이용한 유저 보다 더 이용한 유저의 결제율이 눈에 띄게 높음**
# - 서비스 경험 → 결제 의향에 영향을 준다는 증거
# - 카이제곱 검증 결과도 뒷받침 해주고 있음
# - ★ **1일차 이탈 방지 아이템** 추가 시 체험 횟수가 증가할 가능성 존재 → 결제율 상승 → 수익 증가
# - 2일차까지 이어지는 경험 설계가 전환률의 핵심인 것으로 보여짐

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 6. 미결제 그룹 특성 파악
# - 미결제 그룹 : `trial_day >= 2일 이상 & is_payment==0`
# - 결제 그룹 : `trial_day >= 2일 이상 & is_payment==1`

# %% [markdown]
# - 미결제 그룹(체험 2일이상)
#     - 평균 체류 시간 : `약 17시간`
#     - 평균 총 입실 횟수 : 약 7.3회
#     - 평균 총 퇴실 횟수 : 약 7.1회
#
# - 결제 그룹(체험 2일이상)
#     - 평균 체류 시간 : `약 14시간`
#     - 평균 총 입실 횟수 : 약 6.4회
#     - 평균 총 퇴실 횟수 : 약 6.2회

# %% [markdown]
# - **미 결제그룹이 약 3시간 정도 더 오래 머물렀음**
# - `체류시간 ≠ 결제 전환` 단순히 많이 쓰면 결제한다는 가설이 깨짐 (5번 분석의 가설 깨짐)
# - 많이 이용하고도 결제하지 않는 집단 존재 → 얌체족·체리피커 가능성
#
#    <br>
#
# - ★ 오래 체류했지만 결제하지 않은 이유 :
#   - **가격 불만족**
#   - **오피스 내 인프라 부족(고객경험불만족)**
#   - 지리 or 외부요인 등 다양한 이유가 있을 것 같음
#
#   <br>
#
# - ★ **단순히 체류 기간을 늘리는 전략의 한계점을 발견** → 지금 까지의 데이터로 미뤄 봤을 때
#   - **회원권/요금제 다양화, 가격 설득 장치**
#   - **추가 혜택 제공 및 고객 경험 개선**
#   - **A/B Test 통한 검증 필요**

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 7. site별 가정 지역 특징

# %% [markdown]
# - ### 왕십리 (site 6)
#   - 왕십리역 기준 사무업보단 `먹거리·쇼핑 상권이 활성화 되있음`(대형 쇼핑몰, 전통시장, 대학가 상권 등)
#   - 왕십리역 주변 `한양대/성동구청/성동구의회 등 공공기관들이 존재`
#   - 통계지리정보서비스(SGIS) 기준 `성동구` 내 일자리(행정·사무직, IT 연구개발직, 법률직) 수 정보
#     - `왕십리역` : 13건
#     - `한양대역` : 35건
#     - `성수역` : 710건
#   - 성수역에 사무직군의 비율이 몰려있음
#
#
# <br>
#
# - ### 서울대 (site 2)
#   - `전형적인 대학교 상권과 주변 오피스텔 원룸이 다수 존재`
#   - 2018년도에 `샤로수길이 뜨면서 먹자골목 상권 거래수 크게 증가`
#   - `대기업의 판매점들이 다수 존재`하고 임대료가 매우 높음
#   - 통계지리정보서비스(SGIS) 기준 `영등포구` 내 일자리(행정·사무직, IT 연구개발직, 법률직) 수 정보
#     - `서울대입구역`/`봉천역` : 54건
#     - `신림역` : 41건
#     - `사당역` : 19건
#   - 사무직 자체가 적음
#
#
# <br>
#
# - ### 석촌 (site 3)
#     - `카페·브런치·디저트 중심 상권이 발달(석촌호수/송리단길 영향)`
#     - `주택가와 섞여있으며, 소규모 음식점, 브런치 카페등 생활 밀착형 상권`이 형성됨
#     - 전체적으로 `주거·소매 중심 상권으로 이뤄져있으며`, 대형 사무용 빌딩보다 소형 상업시설 위주로 구성
#     - 통계지리정보서비스(SGIS) 기준 `송파구` 내 일자리(행정·사무직, IT 연구개발직, 법률직) 수 정보
#        - `잠식역` : 269건
#        - `송파나루역` : 45건
#        - `문정역` : 362건
#        - `석촌역` : 36건
#      - 사무직 기반 수요가 적은 편
#
#
# <br>
#
#
# - ### 정동본 (site 1)
#   - `상가건물들이 상당히 노후화 되어있음`
#   - `테이크아웃 커피 전문점들이 굉장히 많음`
#   - 통계지리정보서비스(SGIS) 기준 `중구` 내 일자리(행정·사무직, IT 연구개발직, 법률직) 수 정보
#     - `시청역` : 657건
#     - `충무로역` : 162건
#     - `청구역` : 29건
#     - `시청 vs 충무로` : 약 4.1배 많음
#     - `시청 vs 청구` : 약 22.7배 많음
#   - 위 통계로 보았을 때 사무·전문직들이 밀집되어있는 지역으로 볼 수 있음
#
#
# <br>
#
#
# - ### 공덕 (site 17)
#   - `언론사·대기업 계열사 등 사무실 수요가 높은 직군 존재`
#   - → 원룸·오피스텔 존재 `1 ~ 2인 창업자·프리랜서 수요 흡수`
#   - 통계지리정보서비스(SGIS) 기준 `마포구` 내 일자리(행정·사무직, IT 연구개발직, 법률직) 수 정보
#       - `공덕역` : 263건 → **마포구 내에서 압도적으로 가장 높은 수치**
#       - `마포역` : 39건
#       - `망원역` : 63건
#       - `합정역` : 49건
#       - `홍대입구역` : 174건
#       - `신촌·이대권` : 31건
#       - `상암·디지털미디어시티`(DMC)역 : 126건
#   - 위 통계로 보았을 때 사무·전문직들이 밀집되어있는 지역으로 볼 수 있음
#
#
#
# <br>
#
#
#
# - ### 일산 (site 4)
#   - 주변에 **중소규모 오피스 빌딩·상가건물** 분포 → 소규모 스타트업·전문직 수요와 잘 맞음
#   - 통계지리정보서비스(SGIS) 기준 `일산동구` 내 일자리(행정·사무직, IT 연구개발직, 법률직) 수 정보
#       - `마두역 일대` : `179건`으로, 일산동구에서 가장 높은 수치
#       - `정발산역(23건), 백마역(3건)` 대비 : 약 7.8배, 59.7배 많음
#       - `일산역(2건)` 대비 : 약 89.5배 많음
#   - **마두역 근처는 일산동구 내 사무직 기반 일자리의 중심지**로, 공유오피스 입지로서 경쟁력이 높음

# %% [markdown]
# ---------------------------------------
#
# - 분석 1번을 통해 지점별 결제율 차이 존재 확인
# - 공유오피스 회사 "집무실" → 데이터와 같은 3일 무료체험 시스템 존재하여 지점 평수와 대조하여 지역을 가정하여 대입
#
# <br>
#
# - `사무직 기반 수요가 높은 곳` (정동본, 공덕, 일산)
#     - 상대적으로 결제율이 높거나 평균 이상
#     - 정동본(site 1) : 중구 시청·충무로 일대 사무직 밀집 → 결제율 39.3%
#     - 공덕(site 17) : 언론사·대기업 계열사 등 사무직 수요 많음 → 결제율 34.2% (중하위권이지만 수요 기반층 탄탄하다 판단)
#     - 일산(site4) : 마두역 중심 사무직 수요 → 결제율 39%
# - `주거·상업 중심 상권`(서울대, 석촌, 왕십리)
#     - 서울대(site 2): 대학생·소규모 상권 위주 → 결제율 33.1%
#     - 석촌(site 3): 사무직 수요가 적은편이지만 결제율이 높음 → 결제율 38.6%
#     - 왕십리(site 6): 쇼핑·먹거리 상권 중심, 사무직 적음 → 결제율 34%
#
# <br>
#
# - `지점별 결제율 차이는 입지 특성과 밀접하게 연결되어 있는 것으로 보여짐`
# - `사무직 기반 수요가 많은 지역일수록 결제율이 높고, 상업·주거 상권일수록 낮은 경향이 보여짐`
# - 지점별 특성 맟춤형 마케팅 전략? 이 필요해보임
#
#
#
# 목동 (site 5) = 가장 높은 결제율이지만 원인을 파악해봐야할듯 추가 분석 필요
# site (분당 / 영등포) 47 / 49 : 절대적인 데이터 수가 다른 지점에 비해 적어서 제외

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 8. `trial_day 1, 2, 3` 그룹별 특성 분석

# %% [markdown]
# ### 그룹별 `하루`평균 특성 비교
#
# ![image.png](attachment:image.png)
# - 1일차 그룹 평균 체류시간 약 16,000초 수준
# - 2일차 그룹 약 20,000초 수준
# - 3일차 그룹 약 26,000초 수준
# → 체험일수가 늘어날수록 하루 평균 체류시간도 뚜렷하게 증가하는 패턴
#
# <br>
#
# ![image-2.png](attachment:image-2.png)
# - 체험일수에 따라서 입퇴실 큰 차이 없음
#
# <br>
#
# ![image-3.png](attachment:image-3.png)
# - 모든 일차별 신청한 후 다음 날(`trial_gap==1`) 고객이 압도적 → 보통 수순이라고 생각됨
# - `trial_day`가 높은 유저일수록 `trial_gap` 분포가 `0 ~ 1` 대로 좁혀짐
# - 고객 특징이 보여지는 정도의 참고 데이터로 활용 (trial_day == 3 → 공유오피스를 확실하게 이용하고 싶어하는 고객군 정도)
#
# <br>
#
# ### 그룹별 결제 / 미결제 데이터 수
#
# | Trial Day | 전체 유저 수 | 결제 그룹 | 미결제 그룹 |
# | --------- | ------- | ----- | ------ |
# | **1일차**   | 2,530   | 779   | 1,751  |
# | **2일차**   | 1,779   | 720   | 1,059  |
# | **3일차**   | 1,173   | 519   | 654    |
#
# - ★` 많이 이용한다고 해서 결제로 이어지지 않는 핵심 인사이트 확인`
# - ★`단순히 체류시간 확보 전략보다는 가격·혜택·인프라 요인이 전환에 더 중요한 것으로 보여짐`
#
# <br>
#
# ### 그룹별 체험 기간 내 평균 체류시간
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# - 모든 `trial_day`에서 미결제 그룹의 체류시간이 더 김
# - 많이 쓰는 유저라고 해서 결제율이 높은 게 아님
# - `체류시간 ≠ 결제 전환 가설 붕괴 여기서도 다시 확인`
# - 미결제 그룹: `체리피커 / 얌체족 / 가격 불만족 / 서비스 불만족 일 가능성이 여기서도 보임`
# - `단순히 체류시간을 늘리게 하는 전략은 효율적이지 않음`
# - 오히려 `첫 체험(1일차~2일차)에 가치를 확실히 전달하고`,
# - `추가 혜택·가격 설득·차별화 포인트 제공이 결제 전환에 중요`
#
# <br>
#
#
# ### 그룹별 trial_gap 분포
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
#
# - 모든 `trial_day`에서 `gap=1`일 그룹이 가장 많고, `그 안에서도 결제/미결제가 갈림`
# - 특히 `gap=2~3`일 그룹은 유저 수 자체는 적지만, `결제율이 상대적으로 높은 경향`
# - ☆ 늦게라도 체험을 이어가는 `소수 그룹이 결제 의향이 있음을 확인` → `고객의 첫 경험이 중요한 것으로도 보여짐`

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 9. 퍼널 분석
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ▲ trial_day == 1 인 그룹 특성
# (추가 분석 진행 예정)
# - Trial Gap 분포
#   - 미결제 그룹은 gap=0,1에 많이 몰려 있음 → 신청 즉시/하루 뒤에 써보고 그만두는 경향
#   - 결제 그룹은 gap=1~2에도 꽤 분포 → 약간 텀을 두고 체험 시작한 사람들이 결제로 이어질 확률 ↑
#
# - 평균 체류시간 (결제 vs 미결제, 1일차 한정)
#   - 미결제 그룹의 체류시간이 오히려 더 김 (무료 체험만 길게 쓰고 떠나는 패턴 존재)
#   - 결제 그룹은 상대적으로 짧지만 “필요성 확인 후 빠른 결제” 가능성
# -------------------------------------------------
# - trial_gap=0인 즉시 체험 유저: 호기심만 채우고 쉽게 이탈
# - 장시간 머물렀음에도 미결제: 무료 체험만 활용하는 유저층 존재(얌체족, 먹튀)
# **- ★ 온보딩/첫날 경험 부족: 첫날에 결제까지 이어지지 않으면 2일차에 돌아오지 않을 확률 ↑**

# %% [markdown]
# ### ▲ trial_day == 2 인 그룹 특성
# - Trial Gap 분포
#   - 결제/미결제 모두 gap=1이 가장 많음
#   - **체험 전날 신청 후 다음 날 이용한 고객층이 결제로 이어지는 경우가 많음** → **보통 수순이라고 생각함**
#
# - 평균 체류시간
#   - 미결제 그룹이 오히려 더 오래 머무름 (~43,000초 vs 36,000초)
#   - 1일차와 동일하게 “`무료 체험만 길게 활용하는 층`” 존재
#   - 결제 그룹은 비교적 짧은 시간 체험 → 필요성 확인 후 결제 의사 결정
#
# - Trial Day별 1일 평균 체류시간
#   - 2일차 유저는 1일차보다 평균 체류시간 ↑
#   - 남아있는 사람들은 점점 더 공간 활용도가 커짐
#   - 이탈자는 빠르게 나가고, 잔존자는 점점 충성도가 높아지는 구조
# -------------------------------------------------
# - 2일차에서도 결제 여부는 “`이용시간`”과 비례하지 않음
# - gap=1~2의 계획적 방문자가 결제율 높음
# **- ★체험 지속성(2일차 이상) 자체가 결제 확률을 높이는 요인 → 체류시간이 길수록 서비스에 좋은 경험으로 남는 고객 → 충성도 ↑**

# %% [markdown]
# ### ▲ trial_day == 3 인 그룹 특성
#
# - Trial Gap 분포
#   - 결제/미결제 모두 gap=1이 절대 다수
#   - gap=0(신청 즉시 방문)은 상대적으로 비율이 낮고, 이 그룹에서는 미결제 비중이 더 높음
#   - **즉, 3일차까지 도달한 유저 중에서는 전날 신청 후 다음 날 이용한 고객층이 결제로 이어지는 경우가 많음** → **마찬가지로 보통 수순이라고 생각함**
#
# - 평균 체류시간
#   - 미결제 그룹이 더 오래 머무름 (~86,000초 vs ~71,000초)
#   - 1일차, 2일차와 동일하게 체류시간이 길다고 해서 **결제로 이어지지 않는다는 패턴이 유지**
#   - 결제 그룹은 상대적으로 짧게 써도 **“필요성 확신 → 결제”로 이어짐**
#
# - Trial Day별 1일 평균 체류시간
#   - 1일차 → 2일차 → 3일차 순으로 증가 (약 16,000초 → 20,000초 → 27,000초)
#   - **즉, 남아있는 유저들은 점점 더 많이 쓰면서 충성도가 강화되는 모습**
#
# - 결제 전환율
#   - 3일차 전체 1,173명 중 519명이 결제 → 약 44% 전환
#   - **trial_day == 3 가 1일차·2일차 대비 결제율이 가장 높음**
#   - **하지만 3일차까지 오는 유저 자체가 소수라서 전체 규모는 작음**
# -------------------------------------------------
# - 충성도 높은 소수 : 3일차까지 오는 유저는 이미 몰입도가 높음
# - 미결제 그룹도 평균 체류시간이 상당히 길음
# - “무료로 최대한 뽑아쓰고 결제 안 하는 층”이 3일차에도 여전히 존재(얌체족, 먹튀)
# - **즉시 시작(gap=0)한 그룹보다 gap=1을 둔 그룹에서 결제가 더 잘 일어남**

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 10. trial_day == 1 인 유저 내 trial_gap 0 ~ 1 그룹 , 2 ~ 3 그룹 분리
# - 분석 목적 :
#     - 체험 사용일자가 1인 유저(trial_day==1) 들 중
#     신청을 한 후 본인 스케쥴 때문에 신청 직후에 오지 못하여
#     기간이 지나가 하루만 사용한 유저가 존재한다고 판단하여
#     그 특이점을 확인해보기 위해 분석

# %% [markdown]
# - trial_gap 0 ~ 1 : 1일차 유저 내 신청 직후 체험한 사람
# - trial_gap 2 ~ 3 : 1일차 유저 내 신청 2 ~ 3일 후 사용하러 온 사람(체험 종료일 직전)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# <br>
#
# | 그룹    | 결제 | 미결제 |
# |---------|------|--------|
# | 0~1 그룹 | 542  | 1354   |
# | 2~3 그룹 | 237  | 397    |
#
#
# - 각 그룹별 결제율 비교 카에제곱 검증 결과
#   - 카이제곱 통계량: 16.83685820681525
#   - 자유도: 1
#   - p-value: 4.0734420162381544e-05

# %% [markdown]
# - 0~1 그룹: 일반적인 체험 고객 → 다수이지만 결제율은 낮음
# - 2~3 그룹: 특수 고객군 → 늦게 와서 하루만 사용했음에도 결제율이 높음
#   - `이미 관심도와 니즈가 높았던 고객이 본인 일정 때문에 늦게 왔었을 가능성 존재`
